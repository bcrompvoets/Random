# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Targets with 24 micron data

# %%
df = pd.read_csv("../Data_and_Results/catalog.csv")

MIPS = df.loc[df["24"]!=-99]
print(MIPS.shape[0]/df.shape[0])
print(MIPS.shape)
# MIPS.plot.hist(column="target",bins=[0,1,2,3,4,5,6,7])
# plt.yticks([0,500,1000,1500,2000])
# plt.grid(True)
# df.plot.hist(column="target",bins=[0,1,2,3,4,5,6,7])
# plt.yticks([0,5000,10000,15000,20000])

# plt.grid(True)

# plt.xticks(ticks=[0,1,2,3,4,5,6],labels=["Class I", "Class II", "Gals", "AGNs","PAHs","Shocks","Stars"],rotation = 60)


classes = []
for i in np.arange(0,7):
    classes.append(len(MIPS.loc[MIPS["target"]==i])/len(df.loc[df["target"]==i]))
    print(len(MIPS.loc[MIPS["target"]==i]))
plt.bar([0,1,2,3,4,5,6],classes)
plt.xticks(ticks=[0,1,2,3,4,5,6],labels=["Class I", "Class II", "Gals", "AGNs","PAHs","Shocks","Stars"],rotation = 60)
# Out:
# 0.15511281269746868
# (4173, 16)
# 326
# 2001
# 354
# 559
# 22
# 38
# 873
# ([<matplotlib.axis.XTick at 0x143f49540>,
#   <matplotlib.axis.XTick at 0x143f49510>,
#   <matplotlib.axis.XTick at 0x143f493f0>,
#   <matplotlib.axis.XTick at 0x143f6ecb0>,
#   <matplotlib.axis.XTick at 0x143f6f400>,
#   <matplotlib.axis.XTick at 0x143f6fb50>,
#   <matplotlib.axis.XTick at 0x143f9c2e0>],
#  [Text(0, 0, 'Class I'),
#   Text(1, 0, 'Class II'),
#   Text(2, 0, 'Gals'),
#   Text(3, 0, 'AGNs'),
#   Text(4, 0, 'PAHs'),
#   Text(5, 0, 'Shocks'),
#   Text(6, 0, 'Stars')])

# %% [markdown]
# # CMD Plots

# %%
inputs = np.load("Input_Class_AllClasses_Sep.npy")
gtars = np.load("Target_Class_3Classes_Sep.npy")
ctars = np.load("Pred_Class_AllClasses_Sep.npy")
a = np.where(gtars != ctars)

# %%
# Το see how this data can be separated, we can plot diagrams of the changes between the bands. 
# Because different classes have different amount of envelope material, they will stand out more in different bands.


#Difference between bands is computed as a logarithm - this gives "colour"
def magdif(lowerband,upperband):
  return 2.5*np.log10(lowerband/upperband)


# Plot each class for the difference between each consecutive band ([3.6]-[4.5] vs [4.5]-[5.8], [4.5]-[5.8] vs [5.8]-[8])
# Define the different classes; defined backwards due to how we want to plot them
classes = ["Contaminants", "Class II", "Class I"] 

# Create plot to hold the different colour-colour diagrams
fig,axs = plt.subplots(2,5,figsize=(15,10))

#iterate over and collect vals for [3.6]-[4.5], [4.5]-[5.8], and [5.8]-[8])
for it,cl in enumerate(classes):
  if it ==0: #Want to have Class I most visible, so others needs to be plotted first, corresponds to a target value of 2
    i=2
  elif it ==2: # it==2 means we're in Class I category, corresponds to target value of 0
    i=0
  elif it==1: # it==1 means we're in Class II category, corresponds to target value of 1
    i=1
  #Define variables to hold the data for each colour difference
  Band1 = []#[3.6]-[4.5]
  Band2 = []#[4.5]-[5.8]
  Band3 = []#[5.8]-[8]
  Band4 = []#[3.6]-[5.8]
  Band5 = []#[4.5]-[8]
  Mag45 =[]#[4.5] on it's own
  for index in a[0]: #iterate through the target series
    if gtars[index] == i: # Check that the class of the particular target value is the same as the class being iterated through
      Band1.append(magdif(inputs[index][0],inputs[index][2]))#[3.6]-[4.5]
      Band2.append(magdif(inputs[index][2],inputs[index][4]))#[4.5]-[5.8]
      Band3.append(magdif(inputs[index][4],inputs[index][6]))#[5.8]-[8]
      Band4.append(magdif(inputs[index][0],inputs[index][4]))#[3.6]-[5.8]
      Band5.append(magdif(inputs[index][2],inputs[index][6]))#[4.5]-[8]
      Mag45.append(inputs[index][2]) #[4.5]
  axs[0][0].plot(Band1,Band2,'.',markersize='4',alpha=0.5,label=cl)#[3.6]-[4.5] vs [4.5]-[5.8]
  axs[0][1].plot(Band3,Band2,'.',markersize='4',alpha=0.5,label=cl)#[5.8]-[8] vs [4.5]-[5.8]
  axs[0][2].plot(Band5,Band4,'.',markersize='4',alpha=0.5,label=cl)#[4.5]-[8] vs [3.6]-[5.8]
  axs[0][3].plot(Band3,Band1,'.',markersize='4',alpha=0.5,label=cl)#[5.8]-[8] vs [3.6]-[4.5]
  axs[0][4].plot(Band5,Mag45,'.',markersize='4',alpha=0.5,label=cl)#[4.5]-[8] vs [4.5]
  axs[1][0].hist(Band1,bins=30,density=True,histtype='step',label=cl) # Histogram of [3.6]-[4.5] (each class normalized 1 under the curve)
  axs[1][1].hist(Band2,bins=30,density=True,histtype='step',label=cl) # Histogram of [4.5]-[5.8] (each class normalized 1 under the curve)
  axs[1][2].hist(Band3,bins=30,density=True,histtype='step',label=cl) # Histogram of [5.8]-[8] (each class normalized 1 under the curve)
  axs[1][3].hist(Band4,bins=30,density=True,histtype='step',label=cl) # Histogram of [3.6]-[5.8] (each class normalized 1 under the curve)
  axs[1][4].hist(Band5,bins=30,density=True,histtype='step',label=cl) # Histogram of [4.5]-[8] (each class normalized 1 under the curve)

# Set axes labels
axs[0][0].set_xlabel('[3.6]-[4.5]')
axs[0][0].set_ylabel('[4.5]-[5.8]')
axs[0][1].set_xlabel('[5.8]-[8]')
axs[0][1].set_ylabel('[4.5]-[5.8]')
axs[0][2].set_ylabel('[3.6]-[5.8]')
axs[0][2].set_xlabel('[4.5]-[8]')
axs[0][3].set_ylabel('[3.6]-[4.5]')
axs[0][3].set_xlabel('[5.8]-[8]')
axs[0][2].set_ylabel('[3.6]-[5.8]')
axs[0][2].set_xlabel('[4.5]-[8]')
axs[1][0].set_title('[3.6]-[4.5] Hist')
axs[1][1].set_title('[4.5]-[5.8] Hist')
axs[1][2].set_title('[5.8]-[8] Hist')
axs[1][3].set_title('[3.6]-[5.8] Hist')
axs[1][4].set_title('[4.5]-[8] Hist')
axs[0][4].set_xlabel('[4.5]-[8]')
axs[0][4].set_ylabel('[4.5]')
axs[0][0].legend()
axs[1][0].legend()

# %%
# Το see how this data can be separated, we can plot diagrams of the changes between the bands. 
# Because different classes have different amount of envelope material, they will stand out more in different bands.


#Difference between bands is computed as a logarithm - this gives "colour"
def magdif(lowerband,upperband):
  return 2.5*np.log10(lowerband/upperband)


# Plot each class for the difference between each consecutive band ([3.6]-[4.5] vs [4.5]-[5.8], [4.5]-[5.8] vs [5.8]-[8])
# Define the different classes; defined backwards due to how we want to plot them
classes = ["Contaminants", "Class II", "Class I"] 

# Create plot to hold the different colour-colour diagrams
fig,axs = plt.subplots(2,5,figsize=(15,10))

#iterate over and collect vals for [3.6]-[4.5], [4.5]-[5.8], and [5.8]-[8])
for it,cl in enumerate(classes):
  if it ==0: #Want to have Class I most visible, so others needs to be plotted first, corresponds to a target value of 2
    i=2
  elif it ==2: # it==2 means we're in Class I category, corresponds to target value of 0
    i=0
  elif it==1: # it==1 means we're in Class II category, corresponds to target value of 1
    i=1
  #Define variables to hold the data for each colour difference
  Band1 = []#[3.6]-[4.5]
  Band2 = []#[4.5]-[5.8]
  Band3 = []#[5.8]-[8]
  Band4 = []#[3.6]-[5.8]
  Band5 = []#[4.5]-[8]
  Mag45 =[]#[4.5] on it's own
  for index in a[0]: #iterate through the target series
    if ctars[index] == i and gtars[index] == i-2: # Check that the class of the particular target value is the same as the class being iterated through
      Band1.append(magdif(inputs[index][0],inputs[index][2]))#[3.6]-[4.5]
      Band2.append(magdif(inputs[index][2],inputs[index][4]))#[4.5]-[5.8]
      Band3.append(magdif(inputs[index][4],inputs[index][6]))#[5.8]-[8]
      Band4.append(magdif(inputs[index][0],inputs[index][4]))#[3.6]-[5.8]
      Band5.append(magdif(inputs[index][2],inputs[index][6]))#[4.5]-[8]
      Mag45.append(inputs[index][2]) #[4.5]
  axs[0][0].plot(Band1,Band2,'.',markersize='4',alpha=0.5,label=cl)#[3.6]-[4.5] vs [4.5]-[5.8]
  axs[0][1].plot(Band3,Band2,'.',markersize='4',alpha=0.5,label=cl)#[5.8]-[8] vs [4.5]-[5.8]
  axs[0][2].plot(Band5,Band4,'.',markersize='4',alpha=0.5,label=cl)#[4.5]-[8] vs [3.6]-[5.8]
  axs[0][3].plot(Band3,Band1,'.',markersize='4',alpha=0.5,label=cl)#[5.8]-[8] vs [3.6]-[4.5]
  axs[0][4].plot(Band5,Mag45,'.',markersize='4',alpha=0.5,label=cl)#[4.5]-[8] vs [4.5]
  axs[1][0].hist(Band1,bins=30,density=True,histtype='step',label=cl) # Histogram of [3.6]-[4.5] (each class normalized 1 under the curve)
  axs[1][1].hist(Band2,bins=30,density=True,histtype='step',label=cl) # Histogram of [4.5]-[5.8] (each class normalized 1 under the curve)
  axs[1][2].hist(Band3,bins=30,density=True,histtype='step',label=cl) # Histogram of [5.8]-[8] (each class normalized 1 under the curve)
  axs[1][3].hist(Band4,bins=30,density=True,histtype='step',label=cl) # Histogram of [3.6]-[5.8] (each class normalized 1 under the curve)
  axs[1][4].hist(Band5,bins=30,density=True,histtype='step',label=cl) # Histogram of [4.5]-[8] (each class normalized 1 under the curve)

# Set axes labels
axs[0][0].set_xlabel('[3.6]-[4.5]')
axs[0][0].set_ylabel('[4.5]-[5.8]')
axs[0][1].set_xlabel('[5.8]-[8]')
axs[0][1].set_ylabel('[4.5]-[5.8]')
axs[0][2].set_ylabel('[3.6]-[5.8]')
axs[0][2].set_xlabel('[4.5]-[8]')
axs[0][3].set_ylabel('[3.6]-[4.5]')
axs[0][3].set_xlabel('[5.8]-[8]')
axs[0][2].set_ylabel('[3.6]-[5.8]')
axs[0][2].set_xlabel('[4.5]-[8]')
axs[1][0].set_title('[3.6]-[4.5] Hist')
axs[1][1].set_title('[4.5]-[5.8] Hist')
axs[1][2].set_title('[5.8]-[8] Hist')
axs[1][3].set_title('[3.6]-[5.8] Hist')
axs[1][4].set_title('[4.5]-[8] Hist')
axs[0][4].set_xlabel('[4.5]-[8]')
axs[0][4].set_ylabel('[4.5]')
axs[0][0].legend()
axs[1][0].legend()
# Out:
# /Users/breannacrompvoets/opt/anaconda3/envs/SF/lib/python3.9/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /Users/breannacrompvoets/opt/anaconda3/envs/SF/lib/python3.9/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /Users/breannacrompvoets/opt/anaconda3/envs/SF/lib/python3.9/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /Users/breannacrompvoets/opt/anaconda3/envs/SF/lib/python3.9/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /Users/breannacrompvoets/opt/anaconda3/envs/SF/lib/python3.9/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /Users/breannacrompvoets/opt/anaconda3/envs/SF/lib/python3.9/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /Users/breannacrompvoets/opt/anaconda3/envs/SF/lib/python3.9/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /Users/breannacrompvoets/opt/anaconda3/envs/SF/lib/python3.9/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /Users/breannacrompvoets/opt/anaconda3/envs/SF/lib/python3.9/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /Users/breannacrompvoets/opt/anaconda3/envs/SF/lib/python3.9/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %%
# Το see how this data can be separated, we can plot diagrams of the changes between the bands. 
# Because different classes have different amount of envelope material, they will stand out more in different bands.


#Difference between bands is computed as a logarithm - this gives "colour"
def magdif(lowerband,upperband):
  return 2.5*np.log10(lowerband/upperband)


# Plot each class for the difference between each consecutive band ([3.6]-[4.5] vs [4.5]-[5.8], [4.5]-[5.8] vs [5.8]-[8])
# Define the different classes; defined backwards due to how we want to plot them
classes = ["Contaminants", "Class II", "Class I"] 

# Create plot to hold the different colour-colour diagrams
fig,axs = plt.subplots(2,5,figsize=(15,10))

#iterate over and collect vals for [3.6]-[4.5], [4.5]-[5.8], and [5.8]-[8])
for it,cl in enumerate(classes):
  if it ==0: #Want to have Class I most visible, so others needs to be plotted first, corresponds to a target value of 2
    i=2
  elif it ==2: # it==2 means we're in Class I category, corresponds to target value of 0
    i=0
  elif it==1: # it==1 means we're in Class II category, corresponds to target value of 1
    i=1
  #Define variables to hold the data for each colour difference
  Band1 = []#[3.6]-[4.5]
  Band2 = []#[4.5]-[5.8]
  Band3 = []#[5.8]-[8]
  Band4 = []#[3.6]-[5.8]
  Band5 = []#[4.5]-[8]
  Mag45 =[]#[4.5] on it's own
  for index, tar in enumerate(gtars): #iterate through the target series
    if tar == i: # Check that the class of the particular target value is the same as the class being iterated through
      Band1.append(magdif(inputs[index][0],inputs[index][2]))#[3.6]-[4.5]
      Band2.append(magdif(inputs[index][2],inputs[index][4]))#[4.5]-[5.8]
      Band3.append(magdif(inputs[index][4],inputs[index][6]))#[5.8]-[8]
      Band4.append(magdif(inputs[index][0],inputs[index][4]))#[3.6]-[5.8]
      Band5.append(magdif(inputs[index][2],inputs[index][6]))#[4.5]-[8]
      Mag45.append(inputs[index][2]) #[4.5]
  axs[0][0].plot(Band1,Band2,'.',markersize='4',alpha=0.5,label=cl)#[3.6]-[4.5] vs [4.5]-[5.8]
  axs[0][1].plot(Band3,Band2,'.',markersize='4',alpha=0.5,label=cl)#[5.8]-[8] vs [4.5]-[5.8]
  axs[0][2].plot(Band5,Band4,'.',markersize='4',alpha=0.5,label=cl)#[4.5]-[8] vs [3.6]-[5.8]
  axs[0][3].plot(Band3,Band1,'.',markersize='4',alpha=0.5,label=cl)#[5.8]-[8] vs [3.6]-[4.5]
  axs[0][4].plot(Band5,Mag45,'.',markersize='4',alpha=0.5,label=cl)#[4.5]-[8] vs [4.5]
  axs[1][0].hist(Band1,bins=30,density=True,histtype='step',label=cl) # Histogram of [3.6]-[4.5] (each class normalized 1 under the curve)
  axs[1][1].hist(Band2,bins=30,density=True,histtype='step',label=cl) # Histogram of [4.5]-[5.8] (each class normalized 1 under the curve)
  axs[1][2].hist(Band3,bins=30,density=True,histtype='step',label=cl) # Histogram of [5.8]-[8] (each class normalized 1 under the curve)
  axs[1][3].hist(Band4,bins=30,density=True,histtype='step',label=cl) # Histogram of [3.6]-[5.8] (each class normalized 1 under the curve)
  axs[1][4].hist(Band5,bins=30,density=True,histtype='step',label=cl) # Histogram of [4.5]-[8] (each class normalized 1 under the curve)

# Set axes labels
axs[0][0].set_xlabel('[3.6]-[4.5]')
axs[0][0].set_ylabel('[4.5]-[5.8]')
axs[0][1].set_xlabel('[5.8]-[8]')
axs[0][1].set_ylabel('[4.5]-[5.8]')
axs[0][2].set_ylabel('[3.6]-[5.8]')
axs[0][2].set_xlabel('[4.5]-[8]')
axs[0][3].set_ylabel('[3.6]-[4.5]')
axs[0][3].set_xlabel('[5.8]-[8]')
axs[0][2].set_ylabel('[3.6]-[5.8]')
axs[0][2].set_xlabel('[4.5]-[8]')
axs[1][0].set_title('[3.6]-[4.5] Hist')
axs[1][1].set_title('[4.5]-[5.8] Hist')
axs[1][2].set_title('[5.8]-[8] Hist')
axs[1][3].set_title('[3.6]-[5.8] Hist')
axs[1][4].set_title('[4.5]-[8] Hist')
axs[0][4].set_xlabel('[4.5]-[8]')
axs[0][4].set_ylabel('[4.5]')
axs[0][0].legend()
axs[1][0].legend()

# %%
gtars2 = np.load("Target_Class_AllClasses_Sep.npy")
xaxis = ["Class I", "Class II", "Galaxies", "AGNs", "Shocks", "PAHs","Stars"]
fig, ax = plt.subplots(1,1,figsize=(10,10))
plt.rcParams['font.size'] = 50
plt.title("Data Imbalance",color='white')
plt.rcParams['font.family'] = 'serif'
counts, bins, patches = ax.hist(gtars2,bins=[0,1,2,3,4,5,6,7],align='right',edgecolor='black',color='navy',density=False)
plt.yscale('log')
plt.xticks(ticks=[1,2,3,4,5,6,7],labels=xaxis,rotation = 60,color='white')
plt.yticks(color="white")

for patch, rightside, leftside in zip(patches, bins[1:], bins[:-1]):
    if rightside < 3:
        patch.set_facecolor('maroon')
ax.set_xlim(.5,7.5)
# Out:
# (0.5, 7.5)

# %% [markdown]
# # Misclassifcations

# %%
gtars = np.load("XGB_Val_G-targets2.npy")
gtars2 = np.load("XGB_Val_G-targets7.npy")
filename = "XGB_300s_G-targets_VPred.npy"
# filename = "MLP_CM21_G-targets_VPred.npy" 
# gtars = np.load("MLP_Val_G-targets2.npy")
# gtars2 = np.load("MLP_Val_G-targets7.npy")
# gtars3 = np.load("MLP_CM21_G-targets_VTruthVals.npy") 
preds = np.load(filename)
a = np.where(gtars != preds)

# %%
b1 = np.where(preds[a]==0.)
b2 = np.where(preds[a]==1.)
b3 = np.where(preds[a]==2.)

# %%
class1 = [[],[],[],[],[],[]] 
for x in gtars2[a][b1]:
    if x==1.:
        class1[0].append(x)
    elif x==2.:
        class1[1].append(x)
    elif x==3.:
        class1[2].append(x)
    elif x==4.:
        class1[3].append(x)
    elif x==5.:
        class1[4].append(x)
    elif x==6.:
        class1[5].append(x)
class2 = [[],[],[],[],[],[]]
for x in gtars2[a][b2]:
    if x==0.:
        class2[0].append(x)
    elif x==2.:
        class2[1].append(x)
    elif x==3.:
        class2[2].append(x)
    elif x==4.:
        class2[3].append(x)
    elif x==5.:
        class2[4].append(x)
    elif x==6.:
        class2[5].append(x)
class3 = [[],[]]
for x in gtars2[a][b3]:
    if x==0.:
        class3[0].append(x)
    else:
        class3[1].append(x)

# %%
plt.subplots(1,1,figsize=(12,8))

plt.rcParams['font.size'] = 30
plt.rcParams['font.family'] = 'Palatino'

plt.bar([0,1,2],[0,len(class2[0]),len(class3[0])],label='Class I')
plt.bar([0,1,2],[len(class1[0]),0,len(class3[1])],bottom=[0,len(class2[0]),len(class3[0])],label='Class II')
plt.bar([0,1,2],[len(class1[1]),len(class2[1]),0],bottom=[len(class1[0]),0+len(class2[0]),len(class3[1])+len(class3[0])],label='Galaxy')
plt.bar([0,1,2],[len(class1[2]),len(class2[2]),0],bottom=[len(class1[1])+len(class1[0]),len(class2[1])+len(class2[0]),0],label='AGN')
plt.bar([0,1,2],[len(class1[3]),len(class2[3]),0],bottom=[len(class1[2])+len(class1[1])+len(class1[0]),len(class2[2])+len(class2[1])+len(class2[0]),0],label='Shock')
plt.bar([0,1,2],[len(class1[4]),len(class2[4]),0],bottom=[len(class1[3])+len(class1[2])+len(class1[1])+len(class1[0]),len(class2[3])+len(class2[2])+len(class2[1])+len(class2[0]),0],label='PAH')
plt.bar([0,1,2],[len(class1[5]),len(class2[5]),0],bottom=[len(class1[4])+len(class1[3])+len(class1[2])+len(class1[1])+len(class1[0]),len(class2[4])+len(class2[3])+len(class2[2])+len(class2[1])+len(class2[0]),0],label='Star')
plt.title("Misclassifications")
plt.xlabel("Predicted Class")
plt.ylabel("Counts")
# plt.yticks([0,50,100,150,200,250])
plt.xticks(ticks=[0,1,2],labels=["Class I", "Class II", "Cont."],rotation = 60)
plt.legend()
# Out:
# findfont: Font family ['Palatino'] not found. Falling back to DejaVu Sans.

# %%
totstars = len(np.where(gtars2==6.)[0])
iistars = len(np.where(gtars2[a][b2]==6.)[0])
istars = len(np.where(gtars2[a][b1]==6.)[0])

print((istars+iistars)/totstars*100)

totii = len(np.where(gtars2==1.)[0])
contii = len(np.where(gtars2[a][b3]==1.)[0])
i_ii = len(np.where(gtars2[a][b1]==1.)[0])
print((i_ii+contii)/totii*100)
# Out:
# 4.5283538263901635
# 15.118465588567132

# %% [markdown]
# # Compare all algorithms scatterplot

# %%
plt.subplots(1,1,figsize=(12,8))

plt.rcParams['font.size'] = 30
plt.rcParams['font.family'] = 'Palatino'
# #SVM
# plt.errorbar([0,1,2],[87.4,81.8,87.8],yerr=[9.9,11.6,10.1],color='maroon',label='SVM')
# #LR
# plt.errorbar([0,1,2],[81.6,76.8,82.7],[9.1,10.8,9.7],color='chartreuse',label='LR')
# #Stack
# plt.errorbar([0,1,2],[86.8,81.5,87.5],[9.6,11.3,10.0],color='blue',label='Stack')
# #RF
# plt.errorbar([0,1,2],[87.1,91.4,92.5],[8.6,6.,7.2],color='darkorange',label='RF')
# #GB
# plt.errorbar([0,1,2],[86.2,89.7,91.3],[9.0,7.8,.6],color='rebeccapurple',label='GB')
# #XGB
# plt.errorbar([0,1,2],[88.7,91.6,92.8],[7.2,6.0,6.7],color='hotpink',label='XGB')
# #MLP
# plt.errorbar([0,1,2],[91,92.6,94],[4.9,4.2,4.9],color='forestgreen',label='MLP')

#SVM
plt.errorbar([0,1,2],[91.4,67.9,95.5],yerr=[2.9,3.5,1.9],color='red',fmt='.-',markersize=10,label='SVM (300)')
#LR
plt.errorbar([0,1,2],[85.5,66.,91.2],yerr=[3.4,2.7,1.7],color='orange',fmt='.-',markersize=10,label='LR (300)')
#Stack
plt.errorbar([0,1,2],[89.8,68.5,95.6],yerr=[3.,2.9,1.9],color='blue',fmt='.-',markersize=10,label='Stack (300)')
#RF
plt.errorbar([0,1,2],[87.2,83.9,96],yerr=[3.6,1.9,0.8],color='darkcyan',fmt='.-',markersize=10,label='RF (300)')
#GB
plt.errorbar([0,1,2],[94.8,96.1,98.1],yerr=[3.5,0.9,0.2],color='rebeccapurple',fmt='.-',markersize=10,label='GB (CM21)')
#XGB
plt.errorbar([0,1,2],[88.1,84.1,95.9],yerr=[3.4,1.9,0.8],color='hotpink',fmt='.-',markersize=10,label='XGB (300)')
#MLP
# plt.errorbar([0,1,2],[91,92.6,94],yerr=[2.9,3.5,1.9],color='forestgreen',fmt='.-',markersize=10,label='MLP')
#MLP
plt.errorbar([0,1,2],[93.9,96.8,98.8],color='k',fmt='.-',markersize=10,label='CM21 MLP')

plt.xticks(ticks=[0,1,2],labels=["Class I", "Class II", "Cont."])

plt.legend()
plt.ylim(60,100)
plt.grid(True)
plt.title("G-targets")

plt.ylabel("Recall")

plt.savefig("G_targets_Recall.png",dpi=100)

# %%
plt.subplots(1,1,figsize=(12,8))

# #SVM
# plt.errorbar([0,1,2],[87.4,81.8,87.8],yerr=[9.9,11.6,10.1],color='maroon',label='SVM')
# #LR
# plt.errorbar([0,1,2],[81.6,76.8,82.7],[9.1,10.8,9.7],color='chartreuse',label='LR')
# #Stack
# plt.errorbar([0,1,2],[86.8,81.5,87.5],[9.6,11.3,10.0],color='blue',label='Stack')
# #RF
# plt.errorbar([0,1,2],[87.1,91.4,92.5],[8.6,6.,7.2],color='darkorange',label='RF')
# #GB
# plt.errorbar([0,1,2],[86.2,89.7,91.3],[9.0,7.8,.6],color='rebeccapurple',label='GB')
# #XGB
# plt.errorbar([0,1,2],[88.7,91.6,92.8],[7.2,6.0,6.7],color='hotpink',label='XGB')
# #MLP
# plt.errorbar([0,1,2],[91,92.6,94],[4.9,4.2,4.9],color='forestgreen',label='MLP')

#SVM
plt.errorbar([0,1,2],[97.5,79.7,97.3],yerr=[2.,2.1,0.4],color='red',fmt='.-',markersize=10,label='SVM (300)')
#LR
plt.errorbar([0,1,2],[95.1,75.0,97.0],yerr=[2.,2.4,0.4],color='orange',fmt='.-',markersize=10,label='LR (300)')
#Stack
plt.errorbar([0,1,2],[97.2,79.3,97.9],yerr=[2.2,1.8,0.3],color='blue',fmt='.-',markersize=10,label='Stack (300)')
#RF
plt.errorbar([0,1,2],[94.6,83.2,98.1],yerr=[2.4,1.9,0.3],color='darkcyan',fmt='.-',markersize=10,label='RF (300)')
#GB
plt.errorbar([0,1,2],[96.2,96.5,98.2],yerr=[2.3,1.,0.4],color='rebeccapurple',fmt='.-',markersize=10,label='GB (CM21)')
#XGB
plt.errorbar([0,1,2],[94.3,84.8,98.2],yerr=[2.8,1.7,0.4],color='hotpink',fmt='.-',markersize=10,label='XGB (300)')
#MLP
# plt.errorbar([0,1,2],[],yerr=[2.9,3.5,1.9],color='forestgreen',fmt='.-',markersize=10,label='MLP')
#MLP
plt.errorbar([0,1,2],[93.9,96.8,98.8],yerr=[2.9,3.5,1.9],color='k',fmt='.-',markersize=10,label='CM21 MLP')

plt.xticks(ticks=[0,1,2],labels=["Class I", "Class II", "Cont."])
plt.legend()
plt.ylim(70,100)
plt.grid(True)
plt.title("C-targets")

plt.ylabel("Recall")
plt.savefig("C_targets_Recall.png",dpi=100)

# %%
# For artificially balanced data
import matplotlib.pyplot as plt
plt.subplots(1,1,figsize=(12,8))
#SVM
plt.errorbar([0,1,2],[96,81.4,87.7],yerr=[0.4,0.8,0.6],color='red',fmt='.-',markersize=10,label='SVM')
#LR
plt.errorbar([0,1,2],[97.8,88.2,96.2],yerr=[0.3,0.6,0.4],color='orange',fmt='.-',markersize=10,label='LR')
#Stack
plt.errorbar([0,1,2],[97.9,88.3,96.2],yerr=[0.3,0.6,0.4],color='blue',fmt='.-',markersize=10,label='Stack')
#RF
plt.errorbar([0,1,2],[98.9,92.4,96],yerr=[0.2,0.5,0.4],color='darkcyan',fmt='.-',markersize=10,label='RF')
#GB
plt.errorbar([0,1,2],[98.9,93.8,97],yerr=[0.4,0.7,0.4],color='rebeccapurple',fmt='.-',markersize=10,label='GB')
#XGB
plt.errorbar([0,1,2],[98.8,92.9,95.9],yerr=[0.2,0.5,0.4],color='hotpink',fmt='.-',markersize=10,label='XGB')
#MLP
plt.errorbar([0,1,2],[98,89,96],color='forestgreen',fmt='.-',markersize=10,label='MLP')
# CM21 MLP
plt.errorbar([0,1,2],[93.9,96.8,98.8],color='k',fmt='.-',markersize=10,label='CM21 MLP')

plt.xticks(ticks=[0,1,2],labels=["Class I", "Class II", "Cont."],rotation = 60)
plt.legend()
plt.ylim(70,100)
plt.grid(True)
plt.title("Artificial Balance - Validation Set")

plt.ylabel("Recall")

# plt.savefig("../Figures/G_targets_Artificial_Balance.png",dpi=100)
# Out:
# Text(0, 0.5, 'Recall')
